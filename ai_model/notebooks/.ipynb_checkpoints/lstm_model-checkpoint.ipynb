# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %%
# 예제용 수질 데이터: TOC, TP, TN 등의 연속 측정값
df = pd.read_csv("water_quality_sample.csv")  # 데이터 파일
data = df[['TOC']].values  # 예: TOC만 예측

scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)

# 시퀀스 생성 함수
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len])
    return np.array(X), np.array(y)

SEQ_LEN = 10
X, y = create_sequences(scaled, SEQ_LEN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       1 # # 예제용 수질 데이터: TOC, TP, TN 등의 연속 측정값
#       2 # df = pd.read_csv("water_quality_sample.csv")  # 파일에 따라 컬럼명 맞춰줘
#       3 # data = df[['TOC']].values  # 예: TOC만 예측
#       5 scaler = MinMaxScaler()
# ----> 6 scaled = scaler.fit_transform(data)
#       8 # 시퀀스 생성 함수
#       9 def create_sequences(data, seq_len):
#
# NameError: name 'data' is not defined

# %%
import sys
print(sys.version)
# Out:
# 3.10.18 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:08:55) [MSC v.1929 64 bit (AMD64)]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential([
    LSTM(64, input_shape=(X.shape[1], X.shape[2])),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=10, batch_size=32)

# 저장
model.save("lstm_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import LSTM, Dense
#       4 model = Sequential([
# ----> 5     LSTM(64, input_shape=(X.shape[1], X.shape[2])),
#       6     Dense(1)
#       7 ])
#       8 model.compile(optimizer='adam', loss='mse')
#       9 model.fit(X, y, epochs=10, batch_size=32)
#
# NameError: name 'X' is not defined
